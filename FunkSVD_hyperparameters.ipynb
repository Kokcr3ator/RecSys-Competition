# %% [markdown]
# #### Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as pyplot
import numpy as np

# %%
np.int = int
np.float = float 
np.bool = bool

# %%
URM_all_dataframe = pd.read_csv('data_train.csv', 
                                sep=",", 
                                header= 0, 
                                dtype={0:int, 1:int, 2:float},
                                engine='python')

URM_all_dataframe.columns = ["UserID", "ItemID", "Interaction"]

# %%
URM_all_dataframe.head(n=100)
# Out:
#     UserID  ItemID  Interaction
# 0        1       7          1.0
# 1        1      15          1.0
# 2        1      16          1.0
# 3        1     133          1.0
# 4        1     161          1.0
# ..     ...     ...          ...
# 95       4      47          1.0
# 96       4      70          1.0
# 97       4      79          1.0
# 98       4     119          1.0
# 99       4     125          1.0
#
# [100 rows x 3 columns]

# %%
print ("The number of interactions is {}".format(len(URM_all_dataframe)))
# Out:
# The number of interactions is 478730

# %%
# Extract the list of unique user id and item id 
userID_unique = URM_all_dataframe["UserID"].unique()
itemID_unique = URM_all_dataframe["ItemID"].unique()

# %%
# Display some statistics
n_users = len(userID_unique)
n_items = len(itemID_unique)
n_interactions = len(URM_all_dataframe)

print ("Number of items\t {}, Number of users\t {}".format(n_items, n_users))
print ("Max ID items\t {}, Max Id users\t {}\n".format(max(itemID_unique), max(userID_unique)))
# Out:
# Number of items	 22222, Number of users	 12638
# Max ID items	 22347, Max Id users	 13024

# %%
# Move to sparse format
import scipy.sparse as sps

URM_all = sps.coo_matrix((URM_all_dataframe["Interaction"].values, 
                          (URM_all_dataframe["UserID"].values, URM_all_dataframe["ItemID"].values))) ## .values --> numpy array, df[..] --> pd series

# %%
N_USERS_TRAIN, N_ITEMS_TRAIN = URM_all.shape
print ("Training set: Number of items\t {}, Number of users\t {}".format(N_ITEMS_TRAIN, N_USERS_TRAIN))
# Out:
# Training set: Number of items	 22348, Number of users	 13025

# %% [markdown]
# Maybe removing all the items with no interaction (or no very positive interaction, in our case) can be useful!

# %%
from Evaluation.Evaluator import EvaluatorHoldout
from Data_manager.split_functions.split_train_validation_random_holdout import split_train_in_two_percentage_global_sample

URM_train_validation, URM_test = split_train_in_two_percentage_global_sample(URM_all, train_percentage = 0.8)
URM_train, URM_validation = split_train_in_two_percentage_global_sample(URM_train_validation, train_percentage = 0.8)

evaluator_validation = EvaluatorHoldout(URM_validation, cutoff_list=[10])
evaluator_test = EvaluatorHoldout(URM_test, cutoff_list=[10])
# Out:
# Warning: 593 (4.55 %) of 13025 users have no train items
# Warning: 2517 (19.32 %) of 13025 users have no sampled items
# Warning: 875 (6.72 %) of 13025 users have no train items
# Warning: 2941 (22.58 %) of 13025 users have no sampled items
# EvaluatorHoldout: Ignoring 2941 (22.6%) Users that have less than 1 test interactions
# EvaluatorHoldout: Ignoring 2517 (19.3%) Users that have less than 1 test interactions

# %%
from skopt.space import Real, Integer, Categorical
from HyperparameterTuning.SearchAbstractClass import SearchInputRecommenderArgs

# %%
n_cases = 10  # using 10 as an example
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
hyperparameters_range_dictionary = {
    "epochs": Categorical([800]),
    "num_factors": Integer(1, 200),
    "sgd_mode": Categorical(["sgd", "adagrad", "adam"]),
    "batch_size": Categorical([1, 2, 4, 8, 16, 32, 64, 128, 256, 512, 1024]),
    "item_reg": Real(low = 1e-5, high = 1e-1, prior = 'log-uniform'),
    "user_reg": Real(low = 1e-5, high = 1e-1, prior = 'log-uniform'),
    "learning_rate": Real(low = 1e-4, high = 1e-1, prior = 'log-uniform'),
}

# %%
earlystopping_keywargs = {"validation_every_n": 5,
                          "stop_on_validation": True,
                          "evaluator_object": evaluator_validation,
                          "lower_validations_allowed": 5,
                          "validation_metric": metric_to_optimize,
                          }

# %%
recommender_input_args = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train],     # For a CBF model simply put [URM_train, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {},
    EARLYSTOPPING_KEYWORD_ARGS = earlystopping_keywargs,     # Additional hyperparameters for the fit function
)

# %%
recommender_input_args_last_test = SearchInputRecommenderArgs(
    CONSTRUCTOR_POSITIONAL_ARGS = [URM_train_validation],     # For a CBF model simply put [URM_train_validation, ICM_train]
    CONSTRUCTOR_KEYWORD_ARGS = {},
    FIT_POSITIONAL_ARGS = [],
    FIT_KEYWORD_ARGS = {},
    EARLYSTOPPING_KEYWORD_ARGS = earlystopping_keywargs,     # Additional hyperparameters for the fit function
)

# %%
from Recommenders.MatrixFactorization.Cython.MatrixFactorization_Cython import MatrixFactorization_SVDpp_Cython
from HyperparameterTuning.SearchBayesianSkopt import SearchBayesianSkopt


recommender_class = MatrixFactorization_SVDpp_Cython

hyperparameterSearch = SearchBayesianSkopt(recommender_class,
                                         evaluator_validation=evaluator_validation,
                                         evaluator_test=evaluator_test)

# %%
import os

output_folder_path = "result_experiments_FUNK/"

# If directory does not exist, create
if not os.path.exists(output_folder_path):
    os.makedirs(output_folder_path)
    
n_cases = 10  # using 10 as an example
n_random_starts = int(n_cases*0.3)
metric_to_optimize = "MAP"   
cutoff_to_optimize = 10

# %%
hyperparameterSearch.search(recommender_input_args,
                       recommender_input_args_last_test = recommender_input_args_last_test,
                       hyperparameter_search_space = hyperparameters_range_dictionary,
                       n_cases = n_cases,
                       n_random_starts = n_random_starts,
                       save_model = "last",
                       output_folder_path = output_folder_path, # Where to save the results
                       output_file_name_root = recommender_class.RECOMMENDER_NAME, # How to call the files
                       metric_to_optimize = metric_to_optimize,
                       cutoff_to_optimize = cutoff_to_optimize,
                      )
# Out:
# Iteration No: 1 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'epochs': 800, 'num_factors': 167, 'sgd_mode': 'adam', 'batch_size': 512, 'item_reg': 7.520439410975463e-05, 'user_reg': 0.0029926841643206754, 'learning_rate': 0.00042249375654328735}
# MatrixFactorization_SVDpp_Cython_Recommender: URM Detected 875 ( 6.7%) users with no interactions.
# MatrixFactorization_SVDpp_Cython_Recommender: URM Detected 457 ( 2.0%) items with no interactions.
# SVD++: Processed 306688 (100.0%) in 17.74 sec. MSE loss 6.50E-01. Sample per second: 17286
# SVD++: Epoch 1 of 800. Elapsed time 17.23 sec
# SVD++: Processed 306688 (100.0%) in 17.79 sec. MSE loss 2.11E-01. Sample per second: 17241
# SVD++: Epoch 2 of 800. Elapsed time 34.27 sec
# SVD++: Processed 306688 (100.0%) in 18.31 sec. MSE loss 7.70E-02. Sample per second: 16748
# SVD++: Epoch 3 of 800. Elapsed time 51.81 sec
# SVD++: Processed 306688 (100.0%) in 17.53 sec. MSE loss 3.48E-02. Sample per second: 17496
# SVD++: Epoch 4 of 800. Elapsed time 1.15 min
# SVD++: Processed 306688 (100.0%) in 17.73 sec. MSE loss 1.94E-02. Sample per second: 17299
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 17.65 sec. Users per second: 571
# SVD++: CUTOFF: 10 - PRECISION: 0.0028560, PRECISION_RECALL_MIN_DEN: 0.0052392, RECALL: 0.0045619, MAP: 0.0008598, MAP_MIN_DEN: 0.0016656, MRR: 0.0084585, NDCG: 0.0040664, F1: 0.0035128, HIT_RATE: 0.0281634, ARHR_ALL_HITS: 0.0085280, NOVELTY: 0.0056732, AVERAGE_POPULARITY: 0.0997838, DIVERSITY_MEAN_INTER_LIST: 0.9952086, DIVERSITY_HERFINDAHL: 0.9995110, COVERAGE_ITEM: 0.6470825, COVERAGE_ITEM_HIT: 0.0085019, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0218042, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.2066737, SHANNON_ENTROPY: 12.2696197, RATIO_DIVERSITY_HERFINDAHL: 0.9998725, RATIO_DIVERSITY_GINI: 0.6047909, RATIO_SHANNON_ENTROPY: 0.9460778, RATIO_AVERAGE_POPULARITY: 0.8518565, RATIO_NOVELTY: 0.4155981,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 5 of 800. Elapsed time 1.73 min
# SVD++: Processed 306688 (100.0%) in 17.51 sec. MSE loss 1.28E-02. Sample per second: 17518
# SVD++: Epoch 6 of 800. Elapsed time 2.02 min
# SVD++: Processed 306688 (100.0%) in 17.67 sec. MSE loss 9.13E-03. Sample per second: 17356
# SVD++: Epoch 7 of 800. Elapsed time 2.30 min
# SVD++: Processed 306688 (100.0%) in 18.55 sec. MSE loss 7.00E-03. Sample per second: 16532
# SVD++: Epoch 8 of 800. Elapsed time 2.60 min
# SVD++: Processed 306688 (100.0%) in 18.34 sec. MSE loss 5.60E-03. Sample per second: 16722
# SVD++: Epoch 9 of 800. Elapsed time 2.90 min
# SVD++: Processed 306688 (100.0%) in 17.92 sec. MSE loss 4.63E-03. Sample per second: 17111
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 17.72 sec. Users per second: 569
# SVD++: CUTOFF: 10 - PRECISION: 0.0012396, PRECISION_RECALL_MIN_DEN: 0.0019853, RECALL: 0.0016162, MAP: 0.0003613, MAP_MIN_DEN: 0.0006067, MRR: 0.0035682, NDCG: 0.0015891, F1: 0.0014031, HIT_RATE: 0.0121975, ARHR_ALL_HITS: 0.0035906, NOVELTY: 0.0060712, AVERAGE_POPULARITY: 0.0488587, DIVERSITY_MEAN_INTER_LIST: 0.9980681, DIVERSITY_HERFINDAHL: 0.9997969, COVERAGE_ITEM: 0.7462413, COVERAGE_ITEM_HIT: 0.0053249, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0094434, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.3105781, SHANNON_ENTROPY: 13.0715046, RATIO_DIVERSITY_HERFINDAHL: 1.0001585, RATIO_DIVERSITY_GINI: 0.9088470, RATIO_SHANNON_ENTROPY: 1.0079090, RATIO_AVERAGE_POPULARITY: 0.4171079, RATIO_NOVELTY: 0.4447537,
#
# SVD++: Epoch 10 of 800. Elapsed time 3.49 min
# SVD++: Processed 306688 (100.0%) in 18.38 sec. MSE loss 3.89E-03. Sample per second: 16688
# SVD++: Epoch 11 of 800. Elapsed time 3.78 min
# SVD++: Processed 306688 (100.0%) in 18.85 sec. MSE loss 3.30E-03. Sample per second: 16266
# SVD++: Epoch 12 of 800. Elapsed time 4.09 min
# SVD++: Processed 306688 (100.0%) in 18.36 sec. MSE loss 2.86E-03. Sample per second: 16705
# SVD++: Epoch 13 of 800. Elapsed time 4.38 min
# SVD++: Processed 306688 (100.0%) in 17.64 sec. MSE loss 2.50E-03. Sample per second: 17383
# SVD++: Epoch 14 of 800. Elapsed time 4.67 min
# SVD++: Processed 306688 (100.0%) in 18.15 sec. MSE loss 2.23E-03. Sample per second: 16895
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 16.85 sec. Users per second: 598
# SVD++: CUTOFF: 10 - PRECISION: 0.0009123, PRECISION_RECALL_MIN_DEN: 0.0013907, RECALL: 0.0011188, MAP: 0.0002984, MAP_MIN_DEN: 0.0004760, MRR: 0.0029349, NDCG: 0.0012055, F1: 0.0010051, HIT_RATE: 0.0089250, ARHR_ALL_HITS: 0.0029597, NOVELTY: 0.0062080, AVERAGE_POPULARITY: 0.0368272, DIVERSITY_MEAN_INTER_LIST: 0.9985007, DIVERSITY_HERFINDAHL: 0.9998402, COVERAGE_ITEM: 0.7834258, COVERAGE_ITEM_HIT: 0.0039377, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0069098, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.3531796, SHANNON_ENTROPY: 13.2900965, RATIO_DIVERSITY_HERFINDAHL: 1.0002018, RATIO_DIVERSITY_GINI: 1.0335121, RATIO_SHANNON_ENTROPY: 1.0247640, RATIO_AVERAGE_POPULARITY: 0.3143949, RATIO_NOVELTY: 0.4547726,
#
# SVD++: Epoch 15 of 800. Elapsed time 5.24 min
# SVD++: Processed 306688 (100.0%) in 17.27 sec. MSE loss 1.97E-03. Sample per second: 17761
# SVD++: Epoch 16 of 800. Elapsed time 5.53 min
# SVD++: Processed 306688 (100.0%) in 17.68 sec. MSE loss 1.76E-03. Sample per second: 17349
# SVD++: Epoch 17 of 800. Elapsed time 5.82 min
# SVD++: Processed 306688 (100.0%) in 17.93 sec. MSE loss 1.59E-03. Sample per second: 17105
# SVD++: Epoch 18 of 800. Elapsed time 6.11 min
# SVD++: Processed 306688 (100.0%) in 18.75 sec. MSE loss 1.44E-03. Sample per second: 16358
# SVD++: Epoch 19 of 800. Elapsed time 6.40 min
# SVD++: Processed 306688 (100.0%) in 18.35 sec. MSE loss 1.33E-03. Sample per second: 16712
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 16.64 sec. Users per second: 606
# SVD++: CUTOFF: 10 - PRECISION: 0.0007933, PRECISION_RECALL_MIN_DEN: 0.0011861, RECALL: 0.0009521, MAP: 0.0002830, MAP_MIN_DEN: 0.0004376, MRR: 0.0028055, NDCG: 0.0010827, F1: 0.0008655, HIT_RATE: 0.0078342, ARHR_ALL_HITS: 0.0028179, NOVELTY: 0.0062708, AVERAGE_POPULARITY: 0.0318575, DIVERSITY_MEAN_INTER_LIST: 0.9986440, DIVERSITY_HERFINDAHL: 0.9998545, COVERAGE_ITEM: 0.7958654, COVERAGE_ITEM_HIT: 0.0034455, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0060653, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.3707304, SHANNON_ENTROPY: 13.3711818, RATIO_DIVERSITY_HERFINDAHL: 1.0002161, RATIO_DIVERSITY_GINI: 1.0848713, RATIO_SHANNON_ENTROPY: 1.0310163, RATIO_AVERAGE_POPULARITY: 0.2719684, RATIO_NOVELTY: 0.4593744,
#
# SVD++: Epoch 20 of 800. Elapsed time 6.98 min
# SVD++: Processed 306688 (100.0%) in 17.64 sec. MSE loss 1.20E-03. Sample per second: 17384
# SVD++: Epoch 21 of 800. Elapsed time 7.27 min
# SVD++: Processed 306688 (100.0%) in 18.06 sec. MSE loss 1.09E-03. Sample per second: 16980
# SVD++: Epoch 22 of 800. Elapsed time 7.56 min
# SVD++: Processed 306688 (100.0%) in 17.59 sec. MSE loss 1.01E-03. Sample per second: 17432
# SVD++: Epoch 23 of 800. Elapsed time 7.85 min
# SVD++: Processed 306688 (100.0%) in 18.24 sec. MSE loss 9.25E-04. Sample per second: 16813
# SVD++: Epoch 24 of 800. Elapsed time 8.15 min
# SVD++: Processed 306688 (100.0%) in 17.82 sec. MSE loss 8.50E-04. Sample per second: 17210
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 16.57 sec. Users per second: 609
# SVD++: CUTOFF: 10 - PRECISION: 0.0007636, PRECISION_RECALL_MIN_DEN: 0.0011233, RECALL: 0.0008858, MAP: 0.0002717, MAP_MIN_DEN: 0.0004212, MRR: 0.0027172, NDCG: 0.0010411, F1: 0.0008202, HIT_RATE: 0.0076359, ARHR_ALL_HITS: 0.0027172, NOVELTY: 0.0063044, AVERAGE_POPULARITY: 0.0292320, DIVERSITY_MEAN_INTER_LIST: 0.9987058, DIVERSITY_HERFINDAHL: 0.9998607, COVERAGE_ITEM: 0.8018615, COVERAGE_ITEM_HIT: 0.0033113, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0059117, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.3787797, SHANNON_ENTROPY: 13.4075389, RATIO_DIVERSITY_HERFINDAHL: 1.0002223, RATIO_DIVERSITY_GINI: 1.1084261, RATIO_SHANNON_ENTROPY: 1.0338197, RATIO_AVERAGE_POPULARITY: 0.2495547, RATIO_NOVELTY: 0.4618313,
#
# SVD++: Epoch 25 of 800. Elapsed time 8.72 min
# SVD++: Processed 306688 (100.0%) in 18.21 sec. MSE loss 7.87E-04. Sample per second: 16845
# SVD++: Epoch 26 of 800. Elapsed time 9.01 min
# SVD++: Processed 306688 (100.0%) in 17.81 sec. MSE loss 7.24E-04. Sample per second: 17219
# SVD++: Epoch 27 of 800. Elapsed time 9.30 min
# SVD++: Processed 306688 (100.0%) in 18.52 sec. MSE loss 6.82E-04. Sample per second: 16562
# SVD++: Epoch 28 of 800. Elapsed time 9.60 min
# SVD++: Processed 306688 (100.0%) in 18.32 sec. MSE loss 6.35E-04. Sample per second: 16742
# SVD++: Epoch 29 of 800. Elapsed time 9.90 min
# SVD++: Processed 306688 (100.0%) in 17.81 sec. MSE loss 5.89E-04. Sample per second: 17222
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 16.00 sec. Users per second: 630
# SVD++: CUTOFF: 10 - PRECISION: 0.0007338, PRECISION_RECALL_MIN_DEN: 0.0010694, RECALL: 0.0008364, MAP: 0.0002684, MAP_MIN_DEN: 0.0004134, MRR: 0.0026842, NDCG: 0.0010092, F1: 0.0007818, HIT_RATE: 0.0073384, ARHR_ALL_HITS: 0.0026842, NOVELTY: 0.0063262, AVERAGE_POPULARITY: 0.0276100, DIVERSITY_MEAN_INTER_LIST: 0.9987372, DIVERSITY_HERFINDAHL: 0.9998638, COVERAGE_ITEM: 0.8019062, COVERAGE_ITEM_HIT: 0.0032218, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0056814, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.3823694, SHANNON_ENTROPY: 13.4241276, RATIO_DIVERSITY_HERFINDAHL: 1.0002254, RATIO_DIVERSITY_GINI: 1.1189306, RATIO_SHANNON_ENTROPY: 1.0350988, RATIO_AVERAGE_POPULARITY: 0.2357069, RATIO_NOVELTY: 0.4634278,
#
# SVD++: Convergence reached! Terminating at epoch 30. Best value for 'MAP' at epoch 5 is 0.0009. Elapsed time 10.46 min
# SVD++: Epoch 30 of 800. Elapsed time 10.46 min
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.73 sec. Users per second: 641
# SearchBayesianSkopt: New best config found. Config 0: {'epochs': 5, 'num_factors': 167, 'sgd_mode': 'adam', 'batch_size': 512, 'item_reg': 7.520439410975463e-05, 'user_reg': 0.0029926841643206754, 'learning_rate': 0.00042249375654328735} - results: PRECISION: 0.0028560, PRECISION_RECALL_MIN_DEN: 0.0052392, RECALL: 0.0045619, MAP: 0.0008598, MAP_MIN_DEN: 0.0016656, MRR: 0.0084585, NDCG: 0.0040664, F1: 0.0035128, HIT_RATE: 0.0281634, ARHR_ALL_HITS: 0.0085280, NOVELTY: 0.0056732, AVERAGE_POPULARITY: 0.0997838, DIVERSITY_MEAN_INTER_LIST: 0.9952086, DIVERSITY_HERFINDAHL: 0.9995110, COVERAGE_ITEM: 0.6470825, COVERAGE_ITEM_HIT: 0.0085019, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0218042, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.2066737, SHANNON_ENTROPY: 12.2696197, RATIO_DIVERSITY_HERFINDAHL: 0.9998725, RATIO_DIVERSITY_GINI: 0.6047909, RATIO_SHANNON_ENTROPY: 0.9460778, RATIO_AVERAGE_POPULARITY: 0.8518565, RATIO_NOVELTY: 0.4155981,
#
# EvaluatorHoldout: Processed 10508 (100.0%) in 16.55 sec. Users per second: 635
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'epochs': 5, 'num_factors': 167, 'sgd_mode': 'adam', 'batch_size': 512, 'item_reg': 7.520439410975463e-05, 'user_reg': 0.0029926841643206754, 'learning_rate': 0.00042249375654328735} - results:
# CUTOFF: 10 - PRECISION: 0.0034355, PRECISION_RECALL_MIN_DEN: 0.0054940, RECALL: 0.0044463, MAP: 0.0011735, MAP_MIN_DEN: 0.0018714, MRR: 0.0111223, NDCG: 0.0047064, F1: 0.0038761, HIT_RATE: 0.0325466, ARHR_ALL_HITS: 0.0114179, NOVELTY: 0.0056707, AVERAGE_POPULARITY: 0.0998353, DIVERSITY_MEAN_INTER_LIST: 0.9951830, DIVERSITY_HERFINDAHL: 0.9995088, COVERAGE_ITEM: 0.6558529, COVERAGE_ITEM_HIT: 0.0111867, ITEMS_IN_GT: 0.8014140, COVERAGE_USER: 0.8067562, COVERAGE_USER_HIT: 0.0262572, USERS_IN_GT: 0.8067562, DIVERSITY_GINI: 0.2074872, SHANNON_ENTROPY: 12.2705248, RATIO_DIVERSITY_HERFINDAHL: 0.9998703, RATIO_DIVERSITY_GINI: 0.6071715, RATIO_SHANNON_ENTROPY: 0.9461476, RATIO_AVERAGE_POPULARITY: 0.8522962, RATIO_NOVELTY: 0.4154115,
#
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 660.9004
# Function value obtained: -0.0009
# Current minimum: -0.0009
# Iteration No: 2 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'epochs': 800, 'num_factors': 41, 'sgd_mode': 'adagrad', 'batch_size': 1024, 'item_reg': 0.026049743181850417, 'user_reg': 1.594357029146406e-05, 'learning_rate': 0.007688631476105247}
# MatrixFactorization_SVDpp_Cython_Recommender: URM Detected 875 ( 6.7%) users with no interactions.
# MatrixFactorization_SVDpp_Cython_Recommender: URM Detected 457 ( 2.0%) items with no interactions.
# SVD++: Processed 307200 (100.0%) in 4.12 sec. MSE loss 5.12E-01. Sample per second: 74578
# SVD++: Epoch 1 of 800. Elapsed time 3.97 sec
# SVD++: Processed 307200 (100.0%) in 4.11 sec. MSE loss 2.32E-01. Sample per second: 74821
# SVD++: Epoch 2 of 800. Elapsed time 7.95 sec
# SVD++: Processed 307200 (100.0%) in 4.11 sec. MSE loss 1.35E-01. Sample per second: 74826
# SVD++: Epoch 3 of 800. Elapsed time 11.96 sec
# SVD++: Processed 307200 (100.0%) in 4.05 sec. MSE loss 8.72E-02. Sample per second: 75831
# SVD++: Epoch 4 of 800. Elapsed time 15.90 sec
# SVD++: Processed 307200 (100.0%) in 4.06 sec. MSE loss 5.97E-02. Sample per second: 75723
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.23 sec. Users per second: 662
# SVD++: CUTOFF: 10 - PRECISION: 0.0089845, PRECISION_RECALL_MIN_DEN: 0.0161188, RECALL: 0.0139983, MAP: 0.0029694, MAP_MIN_DEN: 0.0053359, MRR: 0.0278546, NDCG: 0.0128934, F1: 0.0109445, HIT_RATE: 0.0843911, ARHR_ALL_HITS: 0.0287506, NOVELTY: 0.0045925, AVERAGE_POPULARITY: 0.2892477, DIVERSITY_MEAN_INTER_LIST: 0.9552165, DIVERSITY_HERFINDAHL: 0.9955122, COVERAGE_ITEM: 0.0933864, COVERAGE_ITEM_HIT: 0.0098443, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0653359, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.0139128, SHANNON_ENTROPY: 8.5896670, RATIO_DIVERSITY_HERFINDAHL: 0.9958722, RATIO_DIVERSITY_GINI: 0.0407130, RATIO_SHANNON_ENTROPY: 0.6623264, RATIO_AVERAGE_POPULARITY: 2.4693146, RATIO_NOVELTY: 0.3364235,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 5 of 800. Elapsed time 35.16 sec
# SVD++: Processed 307200 (100.0%) in 4.28 sec. MSE loss 4.30E-02. Sample per second: 71748
# SVD++: Epoch 6 of 800. Elapsed time 39.14 sec
# SVD++: Processed 307200 (100.0%) in 4.26 sec. MSE loss 3.24E-02. Sample per second: 72069
# SVD++: Epoch 7 of 800. Elapsed time 43.11 sec
# SVD++: Processed 307200 (100.0%) in 4.15 sec. MSE loss 2.50E-02. Sample per second: 73937
# SVD++: Epoch 8 of 800. Elapsed time 47.01 sec
# SVD++: Processed 307200 (100.0%) in 4.13 sec. MSE loss 1.96E-02. Sample per second: 74377
# SVD++: Epoch 9 of 800. Elapsed time 50.98 sec
# SVD++: Processed 307200 (100.0%) in 4.16 sec. MSE loss 1.61E-02. Sample per second: 73920
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.45 sec. Users per second: 653
# SVD++: CUTOFF: 10 - PRECISION: 0.0069814, PRECISION_RECALL_MIN_DEN: 0.0116281, RECALL: 0.0097756, MAP: 0.0022140, MAP_MIN_DEN: 0.0036463, MRR: 0.0209415, NDCG: 0.0093768, F1: 0.0081455, HIT_RATE: 0.0661444, ARHR_ALL_HITS: 0.0215200, NOVELTY: 0.0047735, AVERAGE_POPULARITY: 0.2222006, DIVERSITY_MEAN_INTER_LIST: 0.9729537, DIVERSITY_HERFINDAHL: 0.9972857, COVERAGE_ITEM: 0.1264095, COVERAGE_ITEM_HIT: 0.0106497, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0512092, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.0223192, SHANNON_ENTROPY: 9.2966762, RATIO_DIVERSITY_HERFINDAHL: 0.9976464, RATIO_DIVERSITY_GINI: 0.0653128, RATIO_SHANNON_ENTROPY: 0.7168420, RATIO_AVERAGE_POPULARITY: 1.8969318, RATIO_NOVELTY: 0.3496876,
#
# SVD++: Epoch 10 of 800. Elapsed time 1.17 min
# SVD++: Processed 307200 (100.0%) in 4.60 sec. MSE loss 1.33E-02. Sample per second: 66833
# SVD++: Epoch 11 of 800. Elapsed time 1.24 min
# SVD++: Processed 307200 (100.0%) in 4.61 sec. MSE loss 1.11E-02. Sample per second: 66607
# SVD++: Epoch 12 of 800. Elapsed time 1.31 min
# SVD++: Processed 307200 (100.0%) in 4.58 sec. MSE loss 9.60E-03. Sample per second: 67122
# SVD++: Epoch 13 of 800. Elapsed time 1.37 min
# SVD++: Processed 307200 (100.0%) in 4.54 sec. MSE loss 8.31E-03. Sample per second: 67639
# SVD++: Epoch 14 of 800. Elapsed time 1.44 min
# SVD++: Processed 307200 (100.0%) in 4.53 sec. MSE loss 7.26E-03. Sample per second: 67881
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.18 sec. Users per second: 664
# SVD++: CUTOFF: 10 - PRECISION: 0.0052757, PRECISION_RECALL_MIN_DEN: 0.0082306, RECALL: 0.0066498, MAP: 0.0015344, MAP_MIN_DEN: 0.0024334, MRR: 0.0145644, NDCG: 0.0065729, F1: 0.0058836, HIT_RATE: 0.0503768, ARHR_ALL_HITS: 0.0149362, NOVELTY: 0.0050379, AVERAGE_POPULARITY: 0.1539139, DIVERSITY_MEAN_INTER_LIST: 0.9849833, DIVERSITY_HERFINDAHL: 0.9984886, COVERAGE_ITEM: 0.1851620, COVERAGE_ITEM_HIT: 0.0118579, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0390019, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.0390004, SHANNON_ENTROPY: 10.1186581, RATIO_DIVERSITY_HERFINDAHL: 0.9988497, RATIO_DIVERSITY_GINI: 0.1141272, RATIO_SHANNON_ENTROPY: 0.7802228, RATIO_AVERAGE_POPULARITY: 1.3139669, RATIO_NOVELTY: 0.3690519,
#
# SVD++: Epoch 15 of 800. Elapsed time 1.76 min
# SVD++: Processed 307200 (100.0%) in 4.72 sec. MSE loss 6.43E-03. Sample per second: 65060
# SVD++: Epoch 16 of 800. Elapsed time 1.83 min
# SVD++: Processed 307200 (100.0%) in 4.70 sec. MSE loss 5.74E-03. Sample per second: 65366
# SVD++: Epoch 17 of 800. Elapsed time 1.89 min
# SVD++: Processed 307200 (100.0%) in 4.67 sec. MSE loss 5.17E-03. Sample per second: 65749
# SVD++: Epoch 18 of 800. Elapsed time 1.96 min
# SVD++: Processed 307200 (100.0%) in 4.65 sec. MSE loss 4.69E-03. Sample per second: 66132
# SVD++: Epoch 19 of 800. Elapsed time 2.02 min
# SVD++: Processed 307200 (100.0%) in 4.63 sec. MSE loss 4.29E-03. Sample per second: 66362
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.33 sec. Users per second: 658
# SVD++: CUTOFF: 10 - PRECISION: 0.0038080, PRECISION_RECALL_MIN_DEN: 0.0056054, RECALL: 0.0044171, MAP: 0.0010205, MAP_MIN_DEN: 0.0014319, MRR: 0.0099177, NDCG: 0.0043732, F1: 0.0040900, HIT_RATE: 0.0370885, ARHR_ALL_HITS: 0.0100563, NOVELTY: 0.0052930, AVERAGE_POPULARITY: 0.1070143, DIVERSITY_MEAN_INTER_LIST: 0.9907286, DIVERSITY_HERFINDAHL: 0.9990630, COVERAGE_ITEM: 0.2497315, COVERAGE_ITEM_HIT: 0.0118579, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0287140, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.0612711, SHANNON_ENTROPY: 10.7837529, RATIO_DIVERSITY_HERFINDAHL: 0.9994243, RATIO_DIVERSITY_GINI: 0.1792982, RATIO_SHANNON_ENTROPY: 0.8315065, RATIO_AVERAGE_POPULARITY: 0.9135832, RATIO_NOVELTY: 0.3877456,
#
# SVD++: Epoch 20 of 800. Elapsed time 2.35 min
# SVD++: Processed 307200 (100.0%) in 3.96 sec. MSE loss 3.92E-03. Sample per second: 77655
# SVD++: Epoch 21 of 800. Elapsed time 2.41 min
# SVD++: Processed 307200 (100.0%) in 4.96 sec. MSE loss 3.64E-03. Sample per second: 61983
# SVD++: Epoch 22 of 800. Elapsed time 2.48 min
# SVD++: Processed 307200 (100.0%) in 4.93 sec. MSE loss 3.37E-03. Sample per second: 62374
# SVD++: Epoch 23 of 800. Elapsed time 2.55 min
# SVD++: Processed 307200 (100.0%) in 4.89 sec. MSE loss 3.14E-03. Sample per second: 62813
# SVD++: Epoch 24 of 800. Elapsed time 2.61 min
# SVD++: Processed 307200 (100.0%) in 4.88 sec. MSE loss 2.95E-03. Sample per second: 63015
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.34 sec. Users per second: 657
# SVD++: CUTOFF: 10 - PRECISION: 0.0027965, PRECISION_RECALL_MIN_DEN: 0.0039400, RECALL: 0.0030704, MAP: 0.0007084, MAP_MIN_DEN: 0.0009585, MRR: 0.0070024, NDCG: 0.0030819, F1: 0.0029270, HIT_RATE: 0.0276676, ARHR_ALL_HITS: 0.0070431, NOVELTY: 0.0055038, AVERAGE_POPULARITY: 0.0785097, DIVERSITY_MEAN_INTER_LIST: 0.9932037, DIVERSITY_HERFINDAHL: 0.9993105, COVERAGE_ITEM: 0.3090209, COVERAGE_ITEM_HIT: 0.0101575, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0214203, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.0850360, SHANNON_ENTROPY: 11.2544442, RATIO_DIVERSITY_HERFINDAHL: 0.9996719, RATIO_DIVERSITY_GINI: 0.2488415, RATIO_SHANNON_ENTROPY: 0.8678003, RATIO_AVERAGE_POPULARITY: 0.6702390, RATIO_NOVELTY: 0.4031856,
#
# SVD++: Epoch 25 of 800. Elapsed time 2.93 min
# SVD++: Processed 307200 (100.0%) in 4.21 sec. MSE loss 2.76E-03. Sample per second: 72985
# SVD++: Epoch 26 of 800. Elapsed time 3.00 min
# SVD++: Processed 307200 (100.0%) in 4.18 sec. MSE loss 2.56E-03. Sample per second: 73444
# SVD++: Epoch 27 of 800. Elapsed time 3.07 min
# SVD++: Processed 307200 (100.0%) in 4.17 sec. MSE loss 2.43E-03. Sample per second: 73737
# SVD++: Epoch 28 of 800. Elapsed time 3.13 min
# SVD++: Processed 307200 (100.0%) in 4.12 sec. MSE loss 2.31E-03. Sample per second: 74602
# SVD++: Epoch 29 of 800. Elapsed time 3.20 min
# SVD++: Processed 307200 (100.0%) in 4.12 sec. MSE loss 2.18E-03. Sample per second: 74581
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.39 sec. Users per second: 655
# SVD++: CUTOFF: 10 - PRECISION: 0.0021222, PRECISION_RECALL_MIN_DEN: 0.0027987, RECALL: 0.0021374, MAP: 0.0005597, MAP_MIN_DEN: 0.0007687, MRR: 0.0055407, NDCG: 0.0023547, F1: 0.0021298, HIT_RATE: 0.0210234, ARHR_ALL_HITS: 0.0055690, NOVELTY: 0.0056729, AVERAGE_POPULARITY: 0.0614324, DIVERSITY_MEAN_INTER_LIST: 0.9945800, DIVERSITY_HERFINDAHL: 0.9994481, COVERAGE_ITEM: 0.3594953, COVERAGE_ITEM_HIT: 0.0085019, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0162764, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.1082179, SHANNON_ENTROPY: 11.5992445, RATIO_DIVERSITY_HERFINDAHL: 0.9998096, RATIO_DIVERSITY_GINI: 0.3166790, RATIO_SHANNON_ENTROPY: 0.8943869, RATIO_AVERAGE_POPULARITY: 0.5244500, RATIO_NOVELTY: 0.4155709,
#
# SVD++: Convergence reached! Terminating at epoch 30. Best value for 'MAP' at epoch 5 is 0.0030. Elapsed time 3.52 min
# SVD++: Epoch 30 of 800. Elapsed time 3.52 min
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.14 sec. Users per second: 666
# SearchBayesianSkopt: New best config found. Config 1: {'epochs': 5, 'num_factors': 41, 'sgd_mode': 'adagrad', 'batch_size': 1024, 'item_reg': 0.026049743181850417, 'user_reg': 1.594357029146406e-05, 'learning_rate': 0.007688631476105247} - results: PRECISION: 0.0089845, PRECISION_RECALL_MIN_DEN: 0.0161188, RECALL: 0.0139983, MAP: 0.0029694, MAP_MIN_DEN: 0.0053359, MRR: 0.0278546, NDCG: 0.0128934, F1: 0.0109445, HIT_RATE: 0.0843911, ARHR_ALL_HITS: 0.0287506, NOVELTY: 0.0045925, AVERAGE_POPULARITY: 0.2892477, DIVERSITY_MEAN_INTER_LIST: 0.9552165, DIVERSITY_HERFINDAHL: 0.9955122, COVERAGE_ITEM: 0.0933864, COVERAGE_ITEM_HIT: 0.0098443, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0653359, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.0139128, SHANNON_ENTROPY: 8.5896670, RATIO_DIVERSITY_HERFINDAHL: 0.9958722, RATIO_DIVERSITY_GINI: 0.0407130, RATIO_SHANNON_ENTROPY: 0.6623264, RATIO_AVERAGE_POPULARITY: 2.4693146, RATIO_NOVELTY: 0.3364235,
#
# EvaluatorHoldout: Processed 10508 (100.0%) in 16.24 sec. Users per second: 647
# SearchBayesianSkopt: Config evaluated with evaluator_test. Config: {'epochs': 5, 'num_factors': 41, 'sgd_mode': 'adagrad', 'batch_size': 1024, 'item_reg': 0.026049743181850417, 'user_reg': 1.594357029146406e-05, 'learning_rate': 0.007688631476105247} - results:
# CUTOFF: 10 - PRECISION: 0.0110487, PRECISION_RECALL_MIN_DEN: 0.0193685, RECALL: 0.0160655, MAP: 0.0035608, MAP_MIN_DEN: 0.0059552, MRR: 0.0323998, NDCG: 0.0150930, F1: 0.0130930, HIT_RATE: 0.1012562, ARHR_ALL_HITS: 0.0339597, NOVELTY: 0.0045947, AVERAGE_POPULARITY: 0.2888945, DIVERSITY_MEAN_INTER_LIST: 0.9554006, DIVERSITY_HERFINDAHL: 0.9955310, COVERAGE_ITEM: 0.0953553, COVERAGE_ITEM_HIT: 0.0107392, ITEMS_IN_GT: 0.8014140, COVERAGE_USER: 0.8067562, COVERAGE_USER_HIT: 0.0816891, USERS_IN_GT: 0.8067562, DIVERSITY_GINI: 0.0140512, SHANNON_ENTROPY: 8.6012888, RATIO_DIVERSITY_HERFINDAHL: 0.9958910, RATIO_DIVERSITY_GINI: 0.0411180, RATIO_SHANNON_ENTROPY: 0.6632225, RATIO_AVERAGE_POPULARITY: 2.4662992, RATIO_NOVELTY: 0.3365851,
#
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 243.5125
# Function value obtained: -0.0030
# Current minimum: -0.0030
# Iteration No: 3 started. Evaluating function at random point.
# SearchBayesianSkopt: Testing config: {'epochs': 800, 'num_factors': 150, 'sgd_mode': 'adam', 'batch_size': 8, 'item_reg': 0.0010721730189155768, 'user_reg': 0.00045245789338409123, 'learning_rate': 0.001031690943456064}
# MatrixFactorization_SVDpp_Cython_Recommender: URM Detected 875 ( 6.7%) users with no interactions.
# MatrixFactorization_SVDpp_Cython_Recommender: URM Detected 457 ( 2.0%) items with no interactions.
# SVD++: Processed 306392 (100.0%) in 17.64 sec. MSE loss 2.13E-02. Sample per second: 17366
# SVD++: Epoch 1 of 800. Elapsed time 16.81 sec
# SVD++: Processed 306392 (100.0%) in 17.62 sec. MSE loss 4.83E-03. Sample per second: 17387
# SVD++: Epoch 2 of 800. Elapsed time 33.80 sec
# SVD++: Processed 306392 (100.0%) in 17.54 sec. MSE loss 2.56E-03. Sample per second: 17464
# SVD++: Epoch 3 of 800. Elapsed time 50.72 sec
# SVD++: Processed 306392 (100.0%) in 17.28 sec. MSE loss 1.56E-03. Sample per second: 17727
# SVD++: Epoch 4 of 800. Elapsed time 1.12 min
# SVD++: Processed 306392 (100.0%) in 17.44 sec. MSE loss 1.02E-03. Sample per second: 17568
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.94 sec. Users per second: 633
# SVD++: CUTOFF: 10 - PRECISION: 0.0001488, PRECISION_RECALL_MIN_DEN: 0.0001620, RECALL: 0.0000958, MAP: 0.0000358, MAP_MIN_DEN: 0.0000387, MRR: 0.0003575, NDCG: 0.0001433, F1: 0.0001166, HIT_RATE: 0.0014875, ARHR_ALL_HITS: 0.0003575, NOVELTY: 0.0069566, AVERAGE_POPULARITY: 0.0057889, DIVERSITY_MEAN_INTER_LIST: 0.9990961, DIVERSITY_HERFINDAHL: 0.9998997, COVERAGE_ITEM: 0.8101844, COVERAGE_ITEM_HIT: 0.0006712, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0011516, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.4476506, SHANNON_ENTROPY: 13.6615214, RATIO_DIVERSITY_HERFINDAHL: 1.0002613, RATIO_DIVERSITY_GINI: 1.3099635, RATIO_SHANNON_ENTROPY: 1.0534036, RATIO_AVERAGE_POPULARITY: 0.0494202, RATIO_NOVELTY: 0.5096085,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 5 of 800. Elapsed time 1.68 min
# SVD++: Processed 306392 (100.0%) in 17.12 sec. MSE loss 7.20E-04. Sample per second: 17896
# SVD++: Epoch 6 of 800. Elapsed time 1.95 min
# SVD++: Processed 306392 (100.0%) in 16.79 sec. MSE loss 5.19E-04. Sample per second: 18249
# SVD++: Epoch 7 of 800. Elapsed time 2.23 min
# SVD++: Processed 306392 (100.0%) in 17.97 sec. MSE loss 3.80E-04. Sample per second: 17052
# SVD++: Epoch 8 of 800. Elapsed time 2.52 min
# SVD++: Processed 306392 (100.0%) in 17.64 sec. MSE loss 2.98E-04. Sample per second: 17368
# SVD++: Epoch 9 of 800. Elapsed time 2.80 min
# SVD++: Processed 306392 (100.0%) in 17.41 sec. MSE loss 2.36E-04. Sample per second: 17598
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 16.03 sec. Users per second: 629
# SVD++: CUTOFF: 10 - PRECISION: 0.0001587, PRECISION_RECALL_MIN_DEN: 0.0001640, RECALL: 0.0000829, MAP: 0.0000282, MAP_MIN_DEN: 0.0000288, MRR: 0.0002816, NDCG: 0.0001285, F1: 0.0001089, HIT_RATE: 0.0015867, ARHR_ALL_HITS: 0.0002816, NOVELTY: 0.0069760, AVERAGE_POPULARITY: 0.0049008, DIVERSITY_MEAN_INTER_LIST: 0.9989634, DIVERSITY_HERFINDAHL: 0.9998864, COVERAGE_ITEM: 0.7585466, COVERAGE_ITEM_HIT: 0.0007159, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0012284, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.4043939, SHANNON_ENTROPY: 13.5192133, RATIO_DIVERSITY_HERFINDAHL: 1.0002480, RATIO_DIVERSITY_GINI: 1.1833811, RATIO_SHANNON_ENTROPY: 1.0424306, RATIO_AVERAGE_POPULARITY: 0.0418382, RATIO_NOVELTY: 0.5110307,
#
# SVD++: Epoch 10 of 800. Elapsed time 3.34 min
# SVD++: Processed 306392 (100.0%) in 17.15 sec. MSE loss 1.95E-04. Sample per second: 17862
# SVD++: Epoch 11 of 800. Elapsed time 3.62 min
# SVD++: Processed 306392 (100.0%) in 16.97 sec. MSE loss 1.57E-04. Sample per second: 18055
# SVD++: Epoch 12 of 800. Elapsed time 3.90 min
# SVD++: Processed 306392 (100.0%) in 17.57 sec. MSE loss 1.27E-04. Sample per second: 17441
# SVD++: Epoch 13 of 800. Elapsed time 4.18 min
# SVD++: Processed 306392 (100.0%) in 17.23 sec. MSE loss 1.09E-04. Sample per second: 17780
# SVD++: Epoch 14 of 800. Elapsed time 4.46 min
# SVD++: Processed 306392 (100.0%) in 17.02 sec. MSE loss 9.36E-05. Sample per second: 18002
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.51 sec. Users per second: 650
# SVD++: CUTOFF: 10 - PRECISION: 0.0000793, PRECISION_RECALL_MIN_DEN: 0.0000836, RECALL: 0.0000496, MAP: 0.0000183, MAP_MIN_DEN: 0.0000189, MRR: 0.0001835, NDCG: 0.0000731, F1: 0.0000610, HIT_RATE: 0.0007933, ARHR_ALL_HITS: 0.0001835, NOVELTY: 0.0069658, AVERAGE_POPULARITY: 0.0044595, DIVERSITY_MEAN_INTER_LIST: 0.9988440, DIVERSITY_HERFINDAHL: 0.9998745, COVERAGE_ITEM: 0.7223913, COVERAGE_ITEM_HIT: 0.0003580, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0006142, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.3728984, SHANNON_ENTROPY: 13.4052487, RATIO_DIVERSITY_HERFINDAHL: 1.0002361, RATIO_DIVERSITY_GINI: 1.0912156, RATIO_SHANNON_ENTROPY: 1.0336431, RATIO_AVERAGE_POPULARITY: 0.0380709, RATIO_NOVELTY: 0.5102823,
#
# SVD++: Epoch 15 of 800. Elapsed time 5.00 min
# SVD++: Processed 306392 (100.0%) in 17.29 sec. MSE loss 7.79E-05. Sample per second: 17723
# SVD++: Epoch 16 of 800. Elapsed time 5.27 min
# SVD++: Processed 306392 (100.0%) in 16.81 sec. MSE loss 6.68E-05. Sample per second: 18227
# SVD++: Epoch 17 of 800. Elapsed time 5.55 min
# SVD++: Processed 306392 (100.0%) in 17.41 sec. MSE loss 6.04E-05. Sample per second: 17602
# SVD++: Epoch 18 of 800. Elapsed time 5.83 min
# SVD++: Processed 306392 (100.0%) in 17.15 sec. MSE loss 5.02E-05. Sample per second: 17869
# SVD++: Epoch 19 of 800. Elapsed time 6.11 min
# SVD++: Processed 306392 (100.0%) in 17.06 sec. MSE loss 4.86E-05. Sample per second: 17962
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.74 sec. Users per second: 641
# SVD++: CUTOFF: 10 - PRECISION: 0.0001388, PRECISION_RECALL_MIN_DEN: 0.0001442, RECALL: 0.0000788, MAP: 0.0000251, MAP_MIN_DEN: 0.0000260, MRR: 0.0002513, NDCG: 0.0001137, F1: 0.0001006, HIT_RATE: 0.0013883, ARHR_ALL_HITS: 0.0002513, NOVELTY: 0.0069406, AVERAGE_POPULARITY: 0.0041659, DIVERSITY_MEAN_INTER_LIST: 0.9987328, DIVERSITY_HERFINDAHL: 0.9998634, COVERAGE_ITEM: 0.6912923, COVERAGE_ITEM_HIT: 0.0006265, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0010749, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.3473608, SHANNON_ENTROPY: 13.3053895, RATIO_DIVERSITY_HERFINDAHL: 1.0002250, RATIO_DIVERSITY_GINI: 1.0164848, RATIO_SHANNON_ENTROPY: 1.0259432, RATIO_AVERAGE_POPULARITY: 0.0355643, RATIO_NOVELTY: 0.5084385,
#
# SVD++: Epoch 20 of 800. Elapsed time 6.65 min
# SVD++: Processed 306392 (100.0%) in 17.54 sec. MSE loss 4.04E-05. Sample per second: 17465
# SVD++: Epoch 21 of 800. Elapsed time 6.93 min
# SVD++: Processed 306392 (100.0%) in 17.17 sec. MSE loss 3.63E-05. Sample per second: 17844
# SVD++: Epoch 22 of 800. Elapsed time 7.21 min
# SVD++: Processed 306392 (100.0%) in 17.47 sec. MSE loss 3.43E-05. Sample per second: 17543
# SVD++: Epoch 23 of 800. Elapsed time 7.49 min
# SVD++: Processed 306392 (100.0%) in 17.18 sec. MSE loss 3.00E-05. Sample per second: 17831
# SVD++: Epoch 24 of 800. Elapsed time 7.77 min
# SVD++: Processed 306392 (100.0%) in 16.93 sec. MSE loss 2.84E-05. Sample per second: 18093
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 16.58 sec. Users per second: 608
# SVD++: CUTOFF: 10 - PRECISION: 0.0001488, PRECISION_RECALL_MIN_DEN: 0.0001541, RECALL: 0.0000817, MAP: 0.0000258, MAP_MIN_DEN: 0.0000266, MRR: 0.0002581, NDCG: 0.0001196, F1: 0.0001055, HIT_RATE: 0.0014875, ARHR_ALL_HITS: 0.0002581, NOVELTY: 0.0069114, AVERAGE_POPULARITY: 0.0039424, DIVERSITY_MEAN_INTER_LIST: 0.9986240, DIVERSITY_HERFINDAHL: 0.9998525, COVERAGE_ITEM: 0.6600591, COVERAGE_ITEM_HIT: 0.0006712, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0011516, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.3245882, SHANNON_ENTROPY: 13.2095602, RATIO_DIVERSITY_HERFINDAHL: 1.0002141, RATIO_DIVERSITY_GINI: 0.9498450, RATIO_SHANNON_ENTROPY: 1.0185541, RATIO_AVERAGE_POPULARITY: 0.0336561, RATIO_NOVELTY: 0.5063034,
#
# SVD++: Epoch 25 of 800. Elapsed time 8.33 min
# SVD++: Processed 306392 (100.0%) in 17.73 sec. MSE loss 2.62E-05. Sample per second: 17281
# SVD++: Epoch 26 of 800. Elapsed time 8.62 min
# SVD++: Processed 306392 (100.0%) in 17.61 sec. MSE loss 2.36E-05. Sample per second: 17395
# SVD++: Epoch 27 of 800. Elapsed time 8.90 min
# SVD++: Processed 306392 (100.0%) in 17.57 sec. MSE loss 2.18E-05. Sample per second: 17442
# SVD++: Epoch 28 of 800. Elapsed time 9.18 min
# SVD++: Processed 306392 (100.0%) in 17.27 sec. MSE loss 2.01E-05. Sample per second: 17745
# SVD++: Epoch 29 of 800. Elapsed time 9.46 min
# SVD++: Processed 306392 (100.0%) in 17.15 sec. MSE loss 1.80E-05. Sample per second: 17859
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 16.48 sec. Users per second: 612
# SVD++: CUTOFF: 10 - PRECISION: 0.0001388, PRECISION_RECALL_MIN_DEN: 0.0001442, RECALL: 0.0000805, MAP: 0.0000234, MAP_MIN_DEN: 0.0000241, MRR: 0.0002338, NDCG: 0.0001102, F1: 0.0001019, HIT_RATE: 0.0013883, ARHR_ALL_HITS: 0.0002338, NOVELTY: 0.0068813, AVERAGE_POPULARITY: 0.0037651, DIVERSITY_MEAN_INTER_LIST: 0.9985053, DIVERSITY_HERFINDAHL: 0.9998406, COVERAGE_ITEM: 0.6314659, COVERAGE_ITEM_HIT: 0.0006265, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0010749, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.3037434, SHANNON_ENTROPY: 13.1153477, RATIO_DIVERSITY_HERFINDAHL: 1.0002022, RATIO_DIVERSITY_GINI: 0.8888468, RATIO_SHANNON_ENTROPY: 1.0112896, RATIO_AVERAGE_POPULARITY: 0.0321427, RATIO_NOVELTY: 0.5040951,
#
# SVD++: Convergence reached! Terminating at epoch 30. Best value for 'MAP' at epoch 5 is 0.0000. Elapsed time 10.01 min
# SVD++: Epoch 30 of 800. Elapsed time 10.01 min
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.78 sec. Users per second: 639
# SearchBayesianSkopt: Config 2 is suboptimal. Config: {'epochs': 5, 'num_factors': 150, 'sgd_mode': 'adam', 'batch_size': 8, 'item_reg': 0.0010721730189155768, 'user_reg': 0.00045245789338409123, 'learning_rate': 0.001031690943456064} - results: PRECISION: 0.0001488, PRECISION_RECALL_MIN_DEN: 0.0001620, RECALL: 0.0000958, MAP: 0.0000358, MAP_MIN_DEN: 0.0000387, MRR: 0.0003575, NDCG: 0.0001433, F1: 0.0001166, HIT_RATE: 0.0014875, ARHR_ALL_HITS: 0.0003575, NOVELTY: 0.0069566, AVERAGE_POPULARITY: 0.0057889, DIVERSITY_MEAN_INTER_LIST: 0.9990961, DIVERSITY_HERFINDAHL: 0.9998997, COVERAGE_ITEM: 0.8101844, COVERAGE_ITEM_HIT: 0.0006712, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0011516, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.4476506, SHANNON_ENTROPY: 13.6615214, RATIO_DIVERSITY_HERFINDAHL: 1.0002613, RATIO_DIVERSITY_GINI: 1.3099635, RATIO_SHANNON_ENTROPY: 1.0534036, RATIO_AVERAGE_POPULARITY: 0.0494202, RATIO_NOVELTY: 0.5096085,
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 618.4476
# Function value obtained: -0.0000
# Current minimum: -0.0030
# Iteration No: 4 started. Searching for the next optimal point.
# SearchBayesianSkopt: Testing config: {'epochs': 800, 'num_factors': 127, 'sgd_mode': 'adagrad', 'batch_size': 512, 'item_reg': 0.00013811047585101383, 'user_reg': 0.0011454262054263534, 'learning_rate': 0.0018300730175222675}
# MatrixFactorization_SVDpp_Cython_Recommender: URM Detected 875 ( 6.7%) users with no interactions.
# MatrixFactorization_SVDpp_Cython_Recommender: URM Detected 457 ( 2.0%) items with no interactions.
# SVD++: Processed 306688 (100.0%) in 12.50 sec. MSE loss 7.95E-01. Sample per second: 24543
# SVD++: Epoch 1 of 800. Elapsed time 12.22 sec
# SVD++: Processed 306688 (100.0%) in 12.64 sec. MSE loss 6.23E-01. Sample per second: 24263
# SVD++: Epoch 2 of 800. Elapsed time 24.37 sec
# SVD++: Processed 306688 (100.0%) in 12.68 sec. MSE loss 5.30E-01. Sample per second: 24185
# SVD++: Epoch 3 of 800. Elapsed time 36.40 sec
# SVD++: Processed 306688 (100.0%) in 12.74 sec. MSE loss 4.65E-01. Sample per second: 24071
# SVD++: Epoch 4 of 800. Elapsed time 48.47 sec
# SVD++: Processed 306688 (100.0%) in 12.74 sec. MSE loss 4.14E-01. Sample per second: 24078
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.69 sec. Users per second: 643
# SVD++: CUTOFF: 10 - PRECISION: 0.0016958, PRECISION_RECALL_MIN_DEN: 0.0027136, RECALL: 0.0022805, MAP: 0.0005391, MAP_MIN_DEN: 0.0008709, MRR: 0.0052453, NDCG: 0.0022811, F1: 0.0019451, HIT_RATE: 0.0165609, ARHR_ALL_HITS: 0.0053109, NOVELTY: 0.0062926, AVERAGE_POPULARITY: 0.0588356, DIVERSITY_MEAN_INTER_LIST: 0.9981273, DIVERSITY_HERFINDAHL: 0.9998028, COVERAGE_ITEM: 0.8240558, COVERAGE_ITEM_HIT: 0.0055486, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0128215, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.3895045, SHANNON_ENTROPY: 13.3427679, RATIO_DIVERSITY_HERFINDAHL: 1.0001644, RATIO_DIVERSITY_GINI: 1.1398100, RATIO_SHANNON_ENTROPY: 1.0288254, RATIO_AVERAGE_POPULARITY: 0.5022809, RATIO_NOVELTY: 0.4609721,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 5 of 800. Elapsed time 1.27 min
# SVD++: Processed 306688 (100.0%) in 12.49 sec. MSE loss 3.73E-01. Sample per second: 24548
# SVD++: Epoch 6 of 800. Elapsed time 1.47 min
# SVD++: Processed 306688 (100.0%) in 12.40 sec. MSE loss 3.40E-01. Sample per second: 24726
# SVD++: Epoch 7 of 800. Elapsed time 1.67 min
# SVD++: Processed 306688 (100.0%) in 12.41 sec. MSE loss 3.11E-01. Sample per second: 24706
# SVD++: Epoch 8 of 800. Elapsed time 1.87 min
# SVD++: Processed 306688 (100.0%) in 12.46 sec. MSE loss 2.87E-01. Sample per second: 24618
# SVD++: Epoch 9 of 800. Elapsed time 2.07 min
# SVD++: Processed 306688 (100.0%) in 12.54 sec. MSE loss 2.65E-01. Sample per second: 24455
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.44 sec. Users per second: 653
# SVD++: CUTOFF: 10 - PRECISION: 0.0029353, PRECISION_RECALL_MIN_DEN: 0.0050858, RECALL: 0.0043653, MAP: 0.0010445, MAP_MIN_DEN: 0.0018044, MRR: 0.0101735, NDCG: 0.0043325, F1: 0.0035103, HIT_RATE: 0.0287584, ARHR_ALL_HITS: 0.0102991, NOVELTY: 0.0059341, AVERAGE_POPULARITY: 0.1000374, DIVERSITY_MEAN_INTER_LIST: 0.9954025, DIVERSITY_HERFINDAHL: 0.9995304, COVERAGE_ITEM: 0.7465992, COVERAGE_ITEM_HIT: 0.0072937, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0222649, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.2840283, SHANNON_ENTROPY: 12.6790427, RATIO_DIVERSITY_HERFINDAHL: 0.9998919, RATIO_DIVERSITY_GINI: 0.8311543, RATIO_SHANNON_ENTROPY: 0.9776473, RATIO_AVERAGE_POPULARITY: 0.8540218, RATIO_NOVELTY: 0.4347065,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 10 of 800. Elapsed time 2.53 min
# SVD++: Processed 306688 (100.0%) in 12.02 sec. MSE loss 2.47E-01. Sample per second: 25516
# SVD++: Epoch 11 of 800. Elapsed time 2.73 min
# SVD++: Processed 306688 (100.0%) in 12.22 sec. MSE loss 2.30E-01. Sample per second: 25096
# SVD++: Epoch 12 of 800. Elapsed time 2.93 min
# SVD++: Processed 306688 (100.0%) in 12.12 sec. MSE loss 2.15E-01. Sample per second: 25306
# SVD++: Epoch 13 of 800. Elapsed time 3.13 min
# SVD++: Processed 306688 (100.0%) in 12.24 sec. MSE loss 2.01E-01. Sample per second: 25065
# SVD++: Epoch 14 of 800. Elapsed time 3.33 min
# SVD++: Processed 306688 (100.0%) in 12.36 sec. MSE loss 1.89E-01. Sample per second: 24807
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 16.33 sec. Users per second: 617
# SVD++: CUTOFF: 10 - PRECISION: 0.0037386, PRECISION_RECALL_MIN_DEN: 0.0069275, RECALL: 0.0060644, MAP: 0.0013810, MAP_MIN_DEN: 0.0025482, MRR: 0.0132932, NDCG: 0.0058170, F1: 0.0046256, HIT_RATE: 0.0360968, ARHR_ALL_HITS: 0.0135415, NOVELTY: 0.0056821, AVERAGE_POPULARITY: 0.1310189, DIVERSITY_MEAN_INTER_LIST: 0.9922528, DIVERSITY_HERFINDAHL: 0.9992154, COVERAGE_ITEM: 0.6783605, COVERAGE_ITEM_HIT: 0.0080992, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0279463, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.2174614, SHANNON_ENTROPY: 12.1270982, RATIO_DIVERSITY_HERFINDAHL: 0.9995768, RATIO_DIVERSITY_GINI: 0.6363590, RATIO_SHANNON_ENTROPY: 0.9350883, RATIO_AVERAGE_POPULARITY: 1.1185113, RATIO_NOVELTY: 0.4162446,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 15 of 800. Elapsed time 3.81 min
# SVD++: Processed 306688 (100.0%) in 12.86 sec. MSE loss 1.78E-01. Sample per second: 23850
# SVD++: Epoch 16 of 800. Elapsed time 4.01 min
# SVD++: Processed 306688 (100.0%) in 13.11 sec. MSE loss 1.68E-01. Sample per second: 23391
# SVD++: Epoch 17 of 800. Elapsed time 4.21 min
# SVD++: Processed 306688 (100.0%) in 12.22 sec. MSE loss 1.59E-01. Sample per second: 25099
# SVD++: Epoch 18 of 800. Elapsed time 4.42 min
# SVD++: Processed 306688 (100.0%) in 12.27 sec. MSE loss 1.51E-01. Sample per second: 24993
# SVD++: Epoch 19 of 800. Elapsed time 4.62 min
# SVD++: Processed 306688 (100.0%) in 12.24 sec. MSE loss 1.43E-01. Sample per second: 25062
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.97 sec. Users per second: 631
# SVD++: CUTOFF: 10 - PRECISION: 0.0044129, PRECISION_RECALL_MIN_DEN: 0.0080919, RECALL: 0.0070916, MAP: 0.0016040, MAP_MIN_DEN: 0.0029631, MRR: 0.0154604, NDCG: 0.0067921, F1: 0.0054404, HIT_RATE: 0.0425426, ARHR_ALL_HITS: 0.0157402, NOVELTY: 0.0055134, AVERAGE_POPULARITY: 0.1526563, DIVERSITY_MEAN_INTER_LIST: 0.9895024, DIVERSITY_HERFINDAHL: 0.9989404, COVERAGE_ITEM: 0.6228298, COVERAGE_ITEM_HIT: 0.0083229, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0329367, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.1759462, SHANNON_ENTROPY: 11.7205825, RATIO_DIVERSITY_HERFINDAHL: 0.9993017, RATIO_DIVERSITY_GINI: 0.5148728, RATIO_SHANNON_ENTROPY: 0.9037430, RATIO_AVERAGE_POPULARITY: 1.3032307, RATIO_NOVELTY: 0.4038901,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 20 of 800. Elapsed time 5.08 min
# SVD++: Processed 306688 (100.0%) in 12.14 sec. MSE loss 1.36E-01. Sample per second: 25262
# SVD++: Epoch 21 of 800. Elapsed time 5.28 min
# SVD++: Processed 306688 (100.0%) in 12.16 sec. MSE loss 1.29E-01. Sample per second: 25229
# SVD++: Epoch 22 of 800. Elapsed time 5.48 min
# SVD++: Processed 306688 (100.0%) in 12.05 sec. MSE loss 1.23E-01. Sample per second: 25451
# SVD++: Epoch 23 of 800. Elapsed time 5.68 min
# SVD++: Processed 306688 (100.0%) in 12.07 sec. MSE loss 1.17E-01. Sample per second: 25416
# SVD++: Epoch 24 of 800. Elapsed time 5.88 min
# SVD++: Processed 306688 (100.0%) in 12.31 sec. MSE loss 1.12E-01. Sample per second: 24906
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.67 sec. Users per second: 644
# SVD++: CUTOFF: 10 - PRECISION: 0.0048988, PRECISION_RECALL_MIN_DEN: 0.0090113, RECALL: 0.0078816, MAP: 0.0017426, MAP_MIN_DEN: 0.0032520, MRR: 0.0167011, NDCG: 0.0074721, F1: 0.0060422, HIT_RATE: 0.0469060, ARHR_ALL_HITS: 0.0170535, NOVELTY: 0.0053915, AVERAGE_POPULARITY: 0.1680011, DIVERSITY_MEAN_INTER_LIST: 0.9872687, DIVERSITY_HERFINDAHL: 0.9987171, COVERAGE_ITEM: 0.5805441, COVERAGE_ITEM_HIT: 0.0087704, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0363148, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.1480960, SHANNON_ENTROPY: 11.4141345, RATIO_DIVERSITY_HERFINDAHL: 0.9990783, RATIO_DIVERSITY_GINI: 0.4333745, RATIO_SHANNON_ENTROPY: 0.8801136, RATIO_AVERAGE_POPULARITY: 1.4342293, RATIO_NOVELTY: 0.3949618,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 25 of 800. Elapsed time 6.35 min
# SVD++: Processed 306688 (100.0%) in 12.19 sec. MSE loss 1.06E-01. Sample per second: 25159
# SVD++: Epoch 26 of 800. Elapsed time 6.55 min
# SVD++: Processed 306688 (100.0%) in 12.21 sec. MSE loss 1.02E-01. Sample per second: 25128
# SVD++: Epoch 27 of 800. Elapsed time 6.75 min
# SVD++: Processed 306688 (100.0%) in 12.40 sec. MSE loss 9.73E-02. Sample per second: 24740
# SVD++: Epoch 28 of 800. Elapsed time 6.95 min
# SVD++: Processed 306688 (100.0%) in 12.61 sec. MSE loss 9.34E-02. Sample per second: 24326
# SVD++: Epoch 29 of 800. Elapsed time 7.16 min
# SVD++: Processed 306688 (100.0%) in 12.65 sec. MSE loss 8.98E-02. Sample per second: 24239
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.63 sec. Users per second: 645
# SVD++: CUTOFF: 10 - PRECISION: 0.0052360, PRECISION_RECALL_MIN_DEN: 0.0096287, RECALL: 0.0084205, MAP: 0.0018238, MAP_MIN_DEN: 0.0033963, MRR: 0.0174223, NDCG: 0.0078882, F1: 0.0064570, HIT_RATE: 0.0498810, ARHR_ALL_HITS: 0.0178202, NOVELTY: 0.0053087, AVERAGE_POPULARITY: 0.1778144, DIVERSITY_MEAN_INTER_LIST: 0.9857400, DIVERSITY_HERFINDAHL: 0.9985642, COVERAGE_ITEM: 0.5454179, COVERAGE_ITEM_HIT: 0.0090836, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0386180, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.1295693, SHANNON_ENTROPY: 11.1991968, RATIO_DIVERSITY_HERFINDAHL: 0.9989254, RATIO_DIVERSITY_GINI: 0.3791596, RATIO_SHANNON_ENTROPY: 0.8635403, RATIO_AVERAGE_POPULARITY: 1.5180058, RATIO_NOVELTY: 0.3888929,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 30 of 800. Elapsed time 7.62 min
# SVD++: Processed 306688 (100.0%) in 12.21 sec. MSE loss 8.60E-02. Sample per second: 25125
# SVD++: Epoch 31 of 800. Elapsed time 7.82 min
# SVD++: Processed 306688 (100.0%) in 12.35 sec. MSE loss 8.24E-02. Sample per second: 24830
# SVD++: Epoch 32 of 800. Elapsed time 8.02 min
# SVD++: Processed 306688 (100.0%) in 12.21 sec. MSE loss 7.95E-02. Sample per second: 25114
# SVD++: Epoch 33 of 800. Elapsed time 8.22 min
# SVD++: Processed 306688 (100.0%) in 12.28 sec. MSE loss 7.64E-02. Sample per second: 24973
# SVD++: Epoch 34 of 800. Elapsed time 8.42 min
# SVD++: Processed 306688 (100.0%) in 12.67 sec. MSE loss 7.34E-02. Sample per second: 24213
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 16.25 sec. Users per second: 621
# SVD++: CUTOFF: 10 - PRECISION: 0.0053154, PRECISION_RECALL_MIN_DEN: 0.0095870, RECALL: 0.0083212, MAP: 0.0018713, MAP_MIN_DEN: 0.0034625, MRR: 0.0178093, NDCG: 0.0079974, F1: 0.0064870, HIT_RATE: 0.0503768, ARHR_ALL_HITS: 0.0182513, NOVELTY: 0.0052487, AVERAGE_POPULARITY: 0.1844062, DIVERSITY_MEAN_INTER_LIST: 0.9846869, DIVERSITY_HERFINDAHL: 0.9984589, COVERAGE_ITEM: 0.5177645, COVERAGE_ITEM_HIT: 0.0093073, ITEMS_IN_GT: 0.7386343, COVERAGE_USER: 0.7742035, COVERAGE_USER_HIT: 0.0390019, USERS_IN_GT: 0.7742035, DIVERSITY_GINI: 0.1164267, SHANNON_ENTROPY: 11.0416276, RATIO_DIVERSITY_HERFINDAHL: 0.9988200, RATIO_DIVERSITY_GINI: 0.3407005, RATIO_SHANNON_ENTROPY: 0.8513906, RATIO_AVERAGE_POPULARITY: 1.5742804, RATIO_NOVELTY: 0.3844968,
#
# SVD++: New best model found! Updating.
# SVD++: Epoch 35 of 800. Elapsed time 8.89 min
# SVD++: Processed 306688 (100.0%) in 12.87 sec. MSE loss 7.05E-02. Sample per second: 23828
# SVD++: Epoch 36 of 800. Elapsed time 9.09 min
# SVD++: Processed 306688 (100.0%) in 12.87 sec. MSE loss 6.80E-02. Sample per second: 23831
# SVD++: Epoch 37 of 800. Elapsed time 9.29 min
# SVD++: Processed 306688 (100.0%) in 12.54 sec. MSE loss 6.59E-02. Sample per second: 24450
# SVD++: Epoch 38 of 800. Elapsed time 9.49 min
# SVD++: Processed 306688 (100.0%) in 12.31 sec. MSE loss 6.35E-02. Sample per second: 24904
# SVD++: Epoch 39 of 800. Elapsed time 9.68 min
# SVD++: Processed 306688 (100.0%) in 12.31 sec. MSE loss 6.10E-02. Sample per second: 24907
# SVD++: Validation begins...
# EvaluatorHoldout: Processed 10084 (100.0%) in 15.72 sec. Users per second: 642
# ...
# SVD++: Epoch 186 of 290. Elapsed time 9.68 min
# SVD++: Processed 384000 (100.0%) in 3.72 sec. MSE loss 1.19E-02. Sample per second: 103118
# SVD++: Epoch 187 of 290. Elapsed time 9.73 min
# SVD++: Processed 384000 (100.0%) in 3.90 sec. MSE loss 1.19E-02. Sample per second: 98566
# SVD++: Epoch 188 of 290. Elapsed time 9.78 min
# SVD++: Processed 384000 (100.0%) in 4.00 sec. MSE loss 1.17E-02. Sample per second: 96075
# SVD++: Epoch 189 of 290. Elapsed time 9.84 min
# SVD++: Processed 384000 (100.0%) in 4.11 sec. MSE loss 1.16E-02. Sample per second: 93375
# SVD++: Epoch 190 of 290. Elapsed time 9.89 min
# SVD++: Processed 384000 (100.0%) in 3.20 sec. MSE loss 1.15E-02. Sample per second: 120124
# SVD++: Epoch 191 of 290. Elapsed time 9.94 min
# SVD++: Processed 384000 (100.0%) in 3.36 sec. MSE loss 1.13E-02. Sample per second: 114292
# SVD++: Epoch 192 of 290. Elapsed time 9.99 min
# SVD++: Processed 384000 (100.0%) in 3.47 sec. MSE loss 1.13E-02. Sample per second: 110798
# SVD++: Epoch 193 of 290. Elapsed time 10.04 min
# SVD++: Processed 384000 (100.0%) in 3.58 sec. MSE loss 1.12E-02. Sample per second: 107199
# SVD++: Epoch 194 of 290. Elapsed time 10.10 min
# SVD++: Processed 384000 (100.0%) in 3.69 sec. MSE loss 1.10E-02. Sample per second: 104061
# SVD++: Epoch 195 of 290. Elapsed time 10.15 min
# SVD++: Processed 384000 (100.0%) in 3.76 sec. MSE loss 1.09E-02. Sample per second: 102165
# SVD++: Epoch 196 of 290. Elapsed time 10.20 min
# SVD++: Processed 384000 (100.0%) in 3.90 sec. MSE loss 1.08E-02. Sample per second: 98390
# SVD++: Epoch 197 of 290. Elapsed time 10.25 min
# SVD++: Processed 384000 (100.0%) in 4.04 sec. MSE loss 1.07E-02. Sample per second: 95068
# SVD++: Epoch 198 of 290. Elapsed time 10.30 min
# SVD++: Processed 384000 (100.0%) in 3.14 sec. MSE loss 1.06E-02. Sample per second: 122293
# SVD++: Epoch 199 of 290. Elapsed time 10.35 min
# SVD++: Processed 384000 (100.0%) in 3.25 sec. MSE loss 1.05E-02. Sample per second: 118297
# SVD++: Epoch 200 of 290. Elapsed time 10.41 min
# SVD++: Processed 384000 (100.0%) in 3.32 sec. MSE loss 1.04E-02. Sample per second: 115800
# SVD++: Epoch 201 of 290. Elapsed time 10.46 min
# SVD++: Processed 384000 (100.0%) in 3.44 sec. MSE loss 1.03E-02. Sample per second: 111543
# SVD++: Epoch 202 of 290. Elapsed time 10.51 min
# SVD++: Processed 384000 (100.0%) in 3.64 sec. MSE loss 1.02E-02. Sample per second: 105532
# SVD++: Epoch 203 of 290. Elapsed time 10.56 min
# SVD++: Processed 384000 (100.0%) in 3.72 sec. MSE loss 1.01E-02. Sample per second: 103135
# SVD++: Epoch 204 of 290. Elapsed time 10.61 min
# SVD++: Processed 384000 (100.0%) in 3.82 sec. MSE loss 1.00E-02. Sample per second: 100422
# SVD++: Epoch 205 of 290. Elapsed time 10.67 min
# SVD++: Processed 384000 (100.0%) in 3.90 sec. MSE loss 9.94E-03. Sample per second: 98563
# SVD++: Epoch 206 of 290. Elapsed time 10.72 min
# SVD++: Processed 384000 (100.0%) in 4.01 sec. MSE loss 9.88E-03. Sample per second: 95848
# SVD++: Epoch 207 of 290. Elapsed time 10.77 min
# SVD++: Processed 384000 (100.0%) in 3.10 sec. MSE loss 9.75E-03. Sample per second: 123817
# SVD++: Epoch 208 of 290. Elapsed time 10.82 min
# SVD++: Processed 384000 (100.0%) in 3.21 sec. MSE loss 9.62E-03. Sample per second: 119711
# SVD++: Epoch 209 of 290. Elapsed time 10.87 min
# SVD++: Processed 384000 (100.0%) in 3.33 sec. MSE loss 9.58E-03. Sample per second: 115366
# SVD++: Epoch 210 of 290. Elapsed time 10.92 min
# SVD++: Processed 384000 (100.0%) in 3.46 sec. MSE loss 9.46E-03. Sample per second: 111128
# SVD++: Epoch 211 of 290. Elapsed time 10.98 min
# SVD++: Processed 384000 (100.0%) in 3.58 sec. MSE loss 9.41E-03. Sample per second: 107152
# SVD++: Epoch 212 of 290. Elapsed time 11.03 min
# SVD++: Processed 384000 (100.0%) in 3.74 sec. MSE loss 9.29E-03. Sample per second: 102688
# SVD++: Epoch 213 of 290. Elapsed time 11.08 min
# SVD++: Processed 384000 (100.0%) in 3.83 sec. MSE loss 9.29E-03. Sample per second: 100171
# SVD++: Epoch 214 of 290. Elapsed time 11.13 min
# SVD++: Processed 384000 (100.0%) in 3.92 sec. MSE loss 9.13E-03. Sample per second: 98045
# SVD++: Epoch 215 of 290. Elapsed time 11.18 min
# SVD++: Processed 384000 (100.0%) in 4.05 sec. MSE loss 9.00E-03. Sample per second: 94921
# SVD++: Epoch 216 of 290. Elapsed time 11.24 min
# SVD++: Processed 384000 (100.0%) in 3.13 sec. MSE loss 9.00E-03. Sample per second: 122732
# SVD++: Epoch 217 of 290. Elapsed time 11.29 min
# SVD++: Processed 384000 (100.0%) in 3.22 sec. MSE loss 8.94E-03. Sample per second: 119108
# SVD++: Epoch 218 of 290. Elapsed time 11.34 min
# SVD++: Processed 384000 (100.0%) in 3.40 sec. MSE loss 8.81E-03. Sample per second: 112854
# SVD++: Epoch 219 of 290. Elapsed time 11.39 min
# SVD++: Processed 384000 (100.0%) in 3.49 sec. MSE loss 8.76E-03. Sample per second: 110146
# SVD++: Epoch 220 of 290. Elapsed time 11.44 min
# SVD++: Processed 384000 (100.0%) in 3.59 sec. MSE loss 8.64E-03. Sample per second: 107054
# SVD++: Epoch 221 of 290. Elapsed time 11.50 min
# SVD++: Processed 384000 (100.0%) in 3.67 sec. MSE loss 8.61E-03. Sample per second: 104766
# SVD++: Epoch 222 of 290. Elapsed time 11.55 min
# SVD++: Processed 384000 (100.0%) in 3.77 sec. MSE loss 8.53E-03. Sample per second: 101784
# SVD++: Epoch 223 of 290. Elapsed time 11.60 min
# SVD++: Processed 384000 (100.0%) in 3.87 sec. MSE loss 8.47E-03. Sample per second: 99126
# SVD++: Epoch 224 of 290. Elapsed time 11.65 min
# SVD++: Processed 384000 (100.0%) in 3.96 sec. MSE loss 8.39E-03. Sample per second: 97051
# SVD++: Epoch 225 of 290. Elapsed time 11.70 min
# SVD++: Processed 384000 (100.0%) in 4.15 sec. MSE loss 8.31E-03. Sample per second: 92507
# SVD++: Epoch 226 of 290. Elapsed time 11.76 min
# SVD++: Processed 384000 (100.0%) in 3.29 sec. MSE loss 8.25E-03. Sample per second: 116842
# SVD++: Epoch 227 of 290. Elapsed time 11.81 min
# SVD++: Processed 384000 (100.0%) in 3.39 sec. MSE loss 8.17E-03. Sample per second: 113095
# SVD++: Epoch 228 of 290. Elapsed time 11.86 min
# SVD++: Processed 384000 (100.0%) in 3.49 sec. MSE loss 8.11E-03. Sample per second: 109996
# SVD++: Epoch 229 of 290. Elapsed time 11.91 min
# SVD++: Processed 384000 (100.0%) in 3.59 sec. MSE loss 8.01E-03. Sample per second: 106820
# SVD++: Epoch 230 of 290. Elapsed time 11.96 min
# SVD++: Processed 384000 (100.0%) in 3.78 sec. MSE loss 8.00E-03. Sample per second: 101660
# SVD++: Epoch 231 of 290. Elapsed time 12.02 min
# SVD++: Processed 384000 (100.0%) in 3.87 sec. MSE loss 7.89E-03. Sample per second: 99294
# SVD++: Epoch 232 of 290. Elapsed time 12.07 min
# SVD++: Processed 384000 (100.0%) in 3.99 sec. MSE loss 7.85E-03. Sample per second: 96177
# SVD++: Epoch 233 of 290. Elapsed time 12.12 min
# SVD++: Processed 384000 (100.0%) in 4.08 sec. MSE loss 7.81E-03. Sample per second: 94204
# SVD++: Epoch 234 of 290. Elapsed time 12.17 min
# SVD++: Processed 384000 (100.0%) in 3.27 sec. MSE loss 7.69E-03. Sample per second: 117389
# SVD++: Epoch 235 of 290. Elapsed time 12.22 min
# SVD++: Processed 384000 (100.0%) in 3.36 sec. MSE loss 7.66E-03. Sample per second: 114179
# SVD++: Epoch 236 of 290. Elapsed time 12.28 min
# SVD++: Processed 384000 (100.0%) in 3.49 sec. MSE loss 7.63E-03. Sample per second: 109876
# SVD++: Epoch 237 of 290. Elapsed time 12.33 min
# SVD++: Processed 384000 (100.0%) in 3.65 sec. MSE loss 7.55E-03. Sample per second: 105350
# SVD++: Epoch 238 of 290. Elapsed time 12.38 min
# SVD++: Processed 384000 (100.0%) in 3.84 sec. MSE loss 7.48E-03. Sample per second: 100005
# SVD++: Epoch 239 of 290. Elapsed time 12.43 min
# SVD++: Processed 384000 (100.0%) in 3.93 sec. MSE loss 7.42E-03. Sample per second: 97750
# SVD++: Epoch 240 of 290. Elapsed time 12.48 min
# SVD++: Processed 384000 (100.0%) in 4.15 sec. MSE loss 7.40E-03. Sample per second: 92526
# SVD++: Epoch 241 of 290. Elapsed time 12.54 min
# SVD++: Processed 384000 (100.0%) in 3.27 sec. MSE loss 7.34E-03. Sample per second: 117481
# SVD++: Epoch 242 of 290. Elapsed time 12.59 min
# SVD++: Processed 384000 (100.0%) in 3.37 sec. MSE loss 7.29E-03. Sample per second: 114074
# SVD++: Epoch 243 of 290. Elapsed time 12.64 min
# SVD++: Processed 384000 (100.0%) in 3.71 sec. MSE loss 7.20E-03. Sample per second: 103636
# SVD++: Epoch 244 of 290. Elapsed time 12.70 min
# SVD++: Processed 384000 (100.0%) in 3.87 sec. MSE loss 7.10E-03. Sample per second: 99206
# SVD++: Epoch 245 of 290. Elapsed time 12.75 min
# SVD++: Processed 384000 (100.0%) in 4.04 sec. MSE loss 7.11E-03. Sample per second: 95133
# SVD++: Epoch 246 of 290. Elapsed time 12.80 min
# SVD++: Processed 384000 (100.0%) in 3.13 sec. MSE loss 7.06E-03. Sample per second: 122497
# SVD++: Epoch 247 of 290. Elapsed time 12.85 min
# SVD++: Processed 384000 (100.0%) in 3.22 sec. MSE loss 7.01E-03. Sample per second: 119233
# SVD++: Epoch 248 of 290. Elapsed time 12.91 min
# SVD++: Processed 384000 (100.0%) in 3.38 sec. MSE loss 6.94E-03. Sample per second: 113708
# SVD++: Epoch 249 of 290. Elapsed time 12.96 min
# SVD++: Processed 384000 (100.0%) in 3.46 sec. MSE loss 6.86E-03. Sample per second: 110877
# SVD++: Epoch 250 of 290. Elapsed time 13.01 min
# SVD++: Processed 384000 (100.0%) in 3.55 sec. MSE loss 6.85E-03. Sample per second: 108099
# SVD++: Epoch 251 of 290. Elapsed time 13.06 min
# SVD++: Processed 384000 (100.0%) in 3.63 sec. MSE loss 6.82E-03. Sample per second: 105807
# SVD++: Epoch 252 of 290. Elapsed time 13.11 min
# SVD++: Processed 384000 (100.0%) in 3.72 sec. MSE loss 6.79E-03. Sample per second: 103130
# SVD++: Epoch 253 of 290. Elapsed time 13.16 min
# SVD++: Processed 384000 (100.0%) in 3.78 sec. MSE loss 6.70E-03. Sample per second: 101467
# SVD++: Epoch 254 of 290. Elapsed time 13.22 min
# SVD++: Processed 384000 (100.0%) in 3.89 sec. MSE loss 6.63E-03. Sample per second: 98718
# SVD++: Epoch 255 of 290. Elapsed time 13.27 min
# SVD++: Processed 384000 (100.0%) in 3.98 sec. MSE loss 6.62E-03. Sample per second: 96444
# SVD++: Epoch 256 of 290. Elapsed time 13.32 min
# SVD++: Processed 384000 (100.0%) in 4.09 sec. MSE loss 6.60E-03. Sample per second: 93789
# SVD++: Epoch 257 of 290. Elapsed time 13.37 min
# SVD++: Processed 384000 (100.0%) in 3.18 sec. MSE loss 6.56E-03. Sample per second: 120661
# SVD++: Epoch 258 of 290. Elapsed time 13.42 min
# SVD++: Processed 384000 (100.0%) in 3.28 sec. MSE loss 6.48E-03. Sample per second: 117195
# SVD++: Epoch 259 of 290. Elapsed time 13.47 min
# SVD++: Processed 384000 (100.0%) in 3.35 sec. MSE loss 6.44E-03. Sample per second: 114673
# SVD++: Epoch 260 of 290. Elapsed time 13.53 min
# SVD++: Processed 384000 (100.0%) in 3.45 sec. MSE loss 6.38E-03. Sample per second: 111298
# SVD++: Epoch 261 of 290. Elapsed time 13.58 min
# SVD++: Processed 384000 (100.0%) in 3.52 sec. MSE loss 6.36E-03. Sample per second: 108978
# SVD++: Epoch 262 of 290. Elapsed time 13.63 min
# SVD++: Processed 384000 (100.0%) in 3.62 sec. MSE loss 6.31E-03. Sample per second: 106161
# SVD++: Epoch 263 of 290. Elapsed time 13.68 min
# SVD++: Processed 384000 (100.0%) in 3.69 sec. MSE loss 6.25E-03. Sample per second: 104095
# SVD++: Epoch 264 of 290. Elapsed time 13.73 min
# SVD++: Processed 384000 (100.0%) in 3.78 sec. MSE loss 6.21E-03. Sample per second: 101596
# SVD++: Epoch 265 of 290. Elapsed time 13.78 min
# SVD++: Processed 384000 (100.0%) in 3.88 sec. MSE loss 6.16E-03. Sample per second: 99085
# SVD++: Epoch 266 of 290. Elapsed time 13.83 min
# SVD++: Processed 384000 (100.0%) in 3.96 sec. MSE loss 6.16E-03. Sample per second: 97015
# SVD++: Epoch 267 of 290. Elapsed time 13.89 min
# SVD++: Processed 384000 (100.0%) in 4.06 sec. MSE loss 6.12E-03. Sample per second: 94456
# SVD++: Epoch 268 of 290. Elapsed time 13.94 min
# SVD++: Processed 384000 (100.0%) in 3.14 sec. MSE loss 6.05E-03. Sample per second: 122118
# SVD++: Epoch 269 of 290. Elapsed time 13.99 min
# SVD++: Processed 384000 (100.0%) in 3.22 sec. MSE loss 5.97E-03. Sample per second: 119215
# SVD++: Epoch 270 of 290. Elapsed time 14.04 min
# SVD++: Processed 384000 (100.0%) in 3.32 sec. MSE loss 6.00E-03. Sample per second: 115703
# SVD++: Epoch 271 of 290. Elapsed time 14.09 min
# SVD++: Processed 384000 (100.0%) in 3.42 sec. MSE loss 5.95E-03. Sample per second: 112382
# SVD++: Epoch 272 of 290. Elapsed time 14.14 min
# SVD++: Processed 384000 (100.0%) in 3.50 sec. MSE loss 5.90E-03. Sample per second: 109723
# SVD++: Epoch 273 of 290. Elapsed time 14.19 min
# SVD++: Processed 384000 (100.0%) in 3.61 sec. MSE loss 5.84E-03. Sample per second: 106305
# SVD++: Epoch 274 of 290. Elapsed time 14.25 min
# SVD++: Processed 384000 (100.0%) in 3.69 sec. MSE loss 5.79E-03. Sample per second: 104091
# SVD++: Epoch 275 of 290. Elapsed time 14.30 min
# SVD++: Processed 384000 (100.0%) in 3.78 sec. MSE loss 5.79E-03. Sample per second: 101594
# SVD++: Epoch 276 of 290. Elapsed time 14.35 min
# SVD++: Processed 384000 (100.0%) in 3.86 sec. MSE loss 5.77E-03. Sample per second: 99348
# SVD++: Epoch 277 of 290. Elapsed time 14.40 min
# SVD++: Processed 384000 (100.0%) in 3.94 sec. MSE loss 5.72E-03. Sample per second: 97439
# SVD++: Epoch 278 of 290. Elapsed time 14.45 min
# SVD++: Processed 384000 (100.0%) in 4.03 sec. MSE loss 5.72E-03. Sample per second: 95275
# SVD++: Epoch 279 of 290. Elapsed time 14.50 min
# SVD++: Processed 384000 (100.0%) in 3.12 sec. MSE loss 5.67E-03. Sample per second: 123093
# SVD++: Epoch 280 of 290. Elapsed time 14.55 min
# SVD++: Processed 384000 (100.0%) in 3.22 sec. MSE loss 5.61E-03. Sample per second: 119316
# SVD++: Epoch 281 of 290. Elapsed time 14.61 min
# SVD++: Processed 384000 (100.0%) in 3.30 sec. MSE loss 5.58E-03. Sample per second: 116219
# SVD++: Epoch 282 of 290. Elapsed time 14.66 min
# SVD++: Processed 384000 (100.0%) in 3.37 sec. MSE loss 5.59E-03. Sample per second: 113825
# SVD++: Epoch 283 of 290. Elapsed time 14.71 min
# SVD++: Processed 384000 (100.0%) in 3.47 sec. MSE loss 5.53E-03. Sample per second: 110770
# SVD++: Epoch 284 of 290. Elapsed time 14.76 min
# SVD++: Processed 384000 (100.0%) in 3.55 sec. MSE loss 5.47E-03. Sample per second: 108019
# SVD++: Epoch 285 of 290. Elapsed time 14.81 min
# SVD++: Processed 384000 (100.0%) in 3.64 sec. MSE loss 5.45E-03. Sample per second: 105591
# SVD++: Epoch 286 of 290. Elapsed time 14.86 min
# SVD++: Processed 384000 (100.0%) in 3.74 sec. MSE loss 5.41E-03. Sample per second: 102650
# SVD++: Epoch 287 of 290. Elapsed time 14.91 min
# SVD++: Processed 384000 (100.0%) in 3.82 sec. MSE loss 5.40E-03. Sample per second: 100518
# SVD++: Epoch 288 of 290. Elapsed time 14.97 min
# SVD++: Processed 384000 (100.0%) in 3.91 sec. MSE loss 5.35E-03. Sample per second: 98208
# SVD++: Epoch 289 of 290. Elapsed time 15.02 min
# SVD++: Processed 384000 (100.0%) in 4.01 sec. MSE loss 5.32E-03. Sample per second: 95657
# SVD++: Epoch 290 of 290. Elapsed time 15.07 min
# SVD++: Terminating at epoch 290. Elapsed time 15.07 min
# EvaluatorHoldout: Processed 10508 (100.0%) in 8.61 sec. Users per second: 1221
# SearchBayesianSkopt: Best config evaluated with evaluator_test with constructor data for final test. Config: {'epochs': 290, 'num_factors': 56, 'sgd_mode': 'adagrad', 'batch_size': 1024, 'item_reg': 0.1, 'user_reg': 0.1, 'learning_rate': 0.0015918885754011409} - results:
# CUTOFF: 10 - PRECISION: 0.0286924, PRECISION_RECALL_MIN_DEN: 0.0539079, RECALL: 0.0462644, MAP: 0.0106522, MAP_MIN_DEN: 0.0195055, MRR: 0.0859059, NDCG: 0.0431051, F1: 0.0354187, HIT_RATE: 0.2326799, ARHR_ALL_HITS: 0.0954870, NOVELTY: 0.0038472, AVERAGE_POPULARITY: 0.7127065, DIVERSITY_MEAN_INTER_LIST: 0.1996141, DIVERSITY_HERFINDAHL: 0.9199595, COVERAGE_ITEM: 0.0130660, COVERAGE_ITEM_HIT: 0.0011187, ITEMS_IN_GT: 0.8014140, COVERAGE_USER: 0.8067562, COVERAGE_USER_HIT: 0.1877159, USERS_IN_GT: 0.8067562, DIVERSITY_GINI: 0.0005974, SHANNON_ENTROPY: 3.7918671, RATIO_DIVERSITY_HERFINDAHL: 0.9202922, RATIO_DIVERSITY_GINI: 0.0017270, RATIO_SHANNON_ENTROPY: 0.2921315, RATIO_AVERAGE_POPULARITY: 6.0443253, RATIO_NOVELTY: 0.2252712,
#
#
# SearchBayesianSkopt: Saving model in result_experiments_FUNK/MatrixFactorization_SVDpp_Cython_Recommender
#
# MatrixFactorization_SVDpp_Cython_Recommender: Saving model in file 'result_experiments_FUNK/MatrixFactorization_SVDpp_Cython_Recommender_best_model_last'
# MatrixFactorization_SVDpp_Cython_Recommender: Saving complete

# %%
from Recommenders.DataIO import DataIO

data_loader = DataIO(folder_path = output_folder_path)
search_metadata = data_loader.load_data(recommender_class.RECOMMENDER_NAME + "_metadata.zip")

search_metadata.keys()
# Out:
# dict_keys(['algorithm_name_recommender', 'algorithm_name_search', 'cutoff_to_optimize', 'exception_list', 'hyperparameters_best', 'hyperparameters_best_index', 'hyperparameters_df', 'metric_to_optimize', 'result_on_earlystopping_df', 'result_on_last', 'result_on_test_best', 'result_on_test_df', 'result_on_validation_best', 'result_on_validation_df', 'time_df', 'time_on_last_df', 'time_on_test_avg', 'time_on_test_total', 'time_on_train_avg', 'time_on_train_total', 'time_on_validation_avg', 'time_on_validation_total'])

# %%
hyperparameters_df = search_metadata["hyperparameters_df"]
hyperparameters_df
# Out:
#   epochs num_factors sgd_mode batch_size  item_reg  user_reg learning_rate
# 0      5         167     adam        512  0.000075  0.002993      0.000422
# 1      5          41  adagrad       1024   0.02605  0.000016      0.007689
# 2      5         150     adam          8  0.001072  0.000452      0.001032
# 3     50         127  adagrad        512  0.000138  0.001145       0.00183
# 4      5         158  adagrad          1  0.000014  0.000095      0.099773
# 5      5           2      sgd          1  0.000231  0.000051      0.000154
# 6      5         166      sgd         32  0.004222  0.003445      0.000693
# 7      5           1      sgd       1024  0.010241  0.037251       0.01067
# 8     10           6  adagrad          4  0.000187  0.098912       0.01188
# 9    290          56  adagrad       1024       0.1       0.1      0.001592

# %%
time_df = search_metadata["time_df"]
time_df
# Out:
#          train validation       test
# 0   627.751454  15.741757  16.566189
# 1   211.506473  15.151663  16.267511
# 2   601.166981  15.809643        NaN
# 3  1141.529805  15.326785        NaN
# 4   577.319536  16.325424        NaN
# 5    97.348252   14.98931        NaN
# 6   228.711997  16.689337        NaN
# 7    95.149482   14.41711        NaN
# 8   129.597735  17.202142        NaN
# 9  2524.702591   7.473447   7.881483

# %%
best_hyperparameters = search_metadata["hyperparameters_best"]
best_hyperparameters
# Out:
# {'epochs': 290,
#  'num_factors': 56,
#  'sgd_mode': 'adagrad',
#  'batch_size': 1024,
#  'item_reg': 0.1,
#  'user_reg': 0.1,
#  'learning_rate': 0.0015918885754011409}
